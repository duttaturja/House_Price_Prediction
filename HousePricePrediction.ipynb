# %% [markdown]
# <a href="https://colab.research.google.com/github/duttaturja/House_Price_Prediction/blob/main/HousePricePrediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
#This imports the drive module from the google.colab package, which is a set of tools specifically created for working with Google Colab.
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
"""
This command mounts your Google Drive to a specific directory in the Colab environment, which in this case is /content/drive.
When this is executed:

Colab will prompt you to authenticate by asking for access to your Google account.
Once you grant access, your Google Drive will be "mounted," meaning it will be accessible like a local file system.
You can now browse, read, or write files in the /content/drive directory as if they were stored locally on Colab."""
# Out:
# '\nThis command mounts your Google Drive to a specific directory in the Colab environment, which in this case is /content/drive.\nWhen this is executed:\n\nColab will prompt you to authenticate by asking for access to your Google account.\nOnce you grant access, your Google Drive will be "mounted," meaning it will be accessible like a local file system.\nYou can now browse, read, or write files in the /content/drive directory as if they were stored locally on Colab.'

# %%
# importing libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import preprocessing as per

# %%
#importing datasets
data1= pd.read_csv('/content/drive/MyDrive/C221026/data.csv')

# %%
data1
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 0         7912     1.5           0     0          3        1340
# 1         9050     2.0           0     4          5        3370
# 2        11947     1.0           0     0          4        1930
# 3         8030     1.0           0     0          4        1000
# 4        10500     1.0           0     0          4        1140
# ...        ...     ...         ...   ...        ...         ...
# 4595      6360     1.0           0     0          4        1510
# 4596      7573     2.0           0     0          3        1460
# 4597      7014     2.0           0     0          3        3010
# 4598      6630     1.0           0     0          3        1070
# 4599      8102     2.0           0     0          4        1490
#
#       sqft_basement  yr_built  yr_renovated                    street  \
# 0                 0      1955          2005      18810 Densmore Ave N
# 1               280      1921             0           709 W Blaine St
# 2                 0      1966             0  26206-26214 143rd Ave SE
# 3              1000      1963             0           857 170th Pl NE
# 4               800      1976          1992         9105 170th Ave NE
# ...             ...       ...           ...                       ...
# 4595              0      1954          1979            501 N 143rd St
# 4596              0      1983          2009          14855 SE 10th Pl
# 4597              0      2009             0          759 Ilwaco Pl NE
# 4598           1020      1974             0         5148 S Creston St
# 4599              0      1990             0         18717 SE 258th St
#
#            city  statezip country
# 0     Shoreline  WA 98133     USA
# 1       Seattle  WA 98119     USA
# 2          Kent  WA 98042     USA
# 3      Bellevue  WA 98008     USA
# 4       Redmond  WA 98052     USA
# ...         ...       ...     ...
# 4595    Seattle  WA 98133     USA
# 4596   Bellevue  WA 98007     USA
# 4597     Renton  WA 98059     USA
# 4598    Seattle  WA 98178     USA
# 4599  Covington  WA 98042     USA
#
# [4600 rows x 18 columns]

# %%
data = data1.drop(columns=['date', 'street', 'city', 'statezip', 'country', 'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated' ])

# %%
data
# Out:
#              price  bedrooms  bathrooms  sqft_living
# 0     3.130000e+05       3.0       1.50         1340
# 1     2.384000e+06       5.0       2.50         3650
# 2     3.420000e+05       3.0       2.00         1930
# 3     4.200000e+05       3.0       2.25         2000
# 4     5.500000e+05       4.0       2.50         1940
# ...            ...       ...        ...          ...
# 4595  3.081667e+05       3.0       1.75         1510
# 4596  5.343333e+05       3.0       2.50         1460
# 4597  4.169042e+05       3.0       2.50         3010
# 4598  2.034000e+05       4.0       2.00         2090
# 4599  2.206000e+05       3.0       2.50         1490
#
# [4600 rows x 4 columns]

# %%
#importing the modules
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
hm = sn.heatmap(data = data)

# %%
data
# Out:
#              price  bedrooms  bathrooms  sqft_living
# 0     3.130000e+05       3.0       1.50         1340
# 1     2.384000e+06       5.0       2.50         3650
# 2     3.420000e+05       3.0       2.00         1930
# 3     4.200000e+05       3.0       2.25         2000
# 4     5.500000e+05       4.0       2.50         1940
# ...            ...       ...        ...          ...
# 4595  3.081667e+05       3.0       1.75         1510
# 4596  5.343333e+05       3.0       2.50         1460
# 4597  4.169042e+05       3.0       2.50         3010
# 4598  2.034000e+05       4.0       2.00         2090
# 4599  2.206000e+05       3.0       2.50         1490
#
# [4600 rows x 4 columns]

# %%
x1 = data.drop(columns=['price'])

# %%
x1
# Out:
#       bedrooms  bathrooms  sqft_living
# 0          3.0       1.50         1340
# 1          5.0       2.50         3650
# 2          3.0       2.00         1930
# 3          3.0       2.25         2000
# 4          4.0       2.50         1940
# ...        ...        ...          ...
# 4595       3.0       1.75         1510
# 4596       3.0       2.50         1460
# 4597       3.0       2.50         3010
# 4598       4.0       2.00         2090
# 4599       3.0       2.50         1490
#
# [4600 rows x 3 columns]

# %%
y1 = data['price']

# %%
y1
# Out:
# 0       3.130000e+05
# 1       2.384000e+06
# 2       3.420000e+05
# 3       4.200000e+05
# 4       5.500000e+05
#             ...
# 4595    3.081667e+05
# 4596    5.343333e+05
# 4597    4.169042e+05
# 4598    2.034000e+05
# 4599    2.206000e+05
# Name: price, Length: 4600, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train1, x_test1, y_train1, y_test1 = train_test_split(x1, y1, test_size = 0.20, random_state = 1)

# %%
"""
1. from sklearn.model_selection import train_test_split:
This imports the train_test_split function from the sklearn.model_selection module, which is part of the scikit-learn library. This function helps in splitting your dataset into training and testing subsets.

2. The train_test_split function:
The function is used to split arrays or matrices into random training and testing subsets. The syntax:

python
Copy code
train_test_split(inputs, targets, test_size=..., random_state=...)
x1: This is your feature data (input variables or independent variables).
y1: This is your target data (labels or dependent variables).
test_size=0.20: Specifies the proportion of the dataset to be included in the test set. In this case, 20% of the data will be used for testing, and 80% for training.
random_state=1: Ensures that the split is reproducible. The same data will be split in the same way if this code is run again with the same random_state value.
3. The Output Variables:
The function returns four arrays:

python
Copy code
x_train1, x_test1, y_train1, y_test1 = train_test_split(x1, y1, test_size= 0.20, random_state=1)
x_train1: Contains 80% of the feature data, used for training the model.
x_test1: Contains 20% of the feature data, used for testing the model’s performance.
y_train1: Contains the corresponding 80% of the target data (labels), used to train the model.
y_test1: Contains the corresponding 20% of the target data (labels), used to evaluate the model on unseen data.
Example:
If you have a dataset with 1000 rows, and you run this code with test_size=0.20, the dataset will be split into:

800 rows in x_train1 and y_train1 (for training),
200 rows in x_test1 and y_test1 (for testing).
This way, the model can be trained on x_train1 and evaluated on x_test1 to check how well it generalizes to new data."""
# Out:
# '\n1. from sklearn.model_selection import train_test_split:\nThis imports the train_test_split function from the sklearn.model_selection module, which is part of the scikit-learn library. This function helps in splitting your dataset into training and testing subsets.\n\n2. The train_test_split function:\nThe function is used to split arrays or matrices into random training and testing subsets. The syntax:\n\npython\nCopy code\ntrain_test_split(inputs, targets, test_size=..., random_state=...)\nx1: This is your feature data (input variables or independent variables).\ny1: This is your target data (labels or dependent variables).\ntest_size=0.20: Specifies the proportion of the dataset to be included in the test set. In this case, 20% of the data will be used for testing, and 80% for training.\nrandom_state=1: Ensures that the split is reproducible. The same data will be split in the same way if this code is run again with the same random_state value.\n3. The Output Variables:\nThe function returns four arrays:\n\npython\nCopy code\nx_train1, x_test1, y_train1, y_test1 = train_test_split(x1, y1, test_size= 0.20, random_state=1)\nx_train1: Contains 80% of the feature data, used for training the model.\nx_test1: Contains 20% of the feature data, used for testing the model’s performance.\ny_train1: Contains the corresponding 80% of the target data (labels), used to train the model.\ny_test1: Contains the corresponding 20% of the target data (labels), used to evaluate the model on unseen data.\nExample:\nIf you have a dataset with 1000 rows, and you run this code with test_size=0.20, the dataset will be split into:\n\n800 rows in x_train1 and y_train1 (for training),\n200 rows in x_test1 and y_test1 (for testing).\nThis way, the model can be trained on x_train1 and evaluated on x_test1 to check how well it generalizes to new data.'

# %%
x_test1
# Out:
#       bedrooms  bathrooms  sqft_living
# 1351       5.0       2.00         2330
# 1687       3.0       2.50         2730
# 1297       3.0       2.00         1220
# 2101       4.0       1.75         2700
# 3920       3.0       4.00         2080
# ...        ...        ...          ...
# 4487       4.0       1.00         2080
# 2215       2.0       1.00         1740
# 3634       3.0       3.00         3790
# 3531       4.0       2.25         2300
# 3955       3.0       1.75         1630
#
# [920 rows x 3 columns]

# %%
y_test1.to_csv('/content/data.csv')

# %%
pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.8.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 7.1 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.7

# %%
from sklearn.datasets import load_diabetes
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import VotingRegressor
from catboost import CatBoostRegressor
from xgboost.sklearn import XGBRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn import linear_model


#Linear Regression
from sklearn.linear_model import LinearRegression
#regressor = LinearRegression()

#Stochastic Gradient Descent Regression (rejected)
from sklearn.linear_model import SGDRegressor
#regressor = SGDRegressor()

#XGBoost Regressor
#Best Hyperparameters:  {'learning_rate': 0.05414335252326741, 'max_depth': 1, 'subsample': 0.5720719776204785, 'colsample_bytree': 0.7621439558577735, 'min_child_weight': 14}

from xgboost.sklearn import XGBRegressor
regressor = XGBRegressor(learning_rate= 0.05414335252326741, max_depth= 1, subsample= 0.5720719776204785, colsample_bytree= 0.7621439558577735, min_child_weight= 14)

#LGBM Regressor
from lightgbm import LGBMRegressor
#regressor = LGBMRegressor()

#CatBoost Regressor
from catboost import CatBoostRegressor
#regressor = CatBoostRegressor()

#Kernel Ridge Regression
from sklearn.kernel_ridge import KernelRidge
#regressor = KernelRidge()

#Elastic Net Regression
from sklearn.linear_model import ElasticNet
#regressor = ElasticNet()

#Bayesian Ridge Regression
from sklearn.linear_model import BayesianRidge
#regressor = BayesianRidge()

#Gradient Boosting Regression
from sklearn.ensemble import GradientBoostingRegressor
#regressor = GradientBoostingRegressor()

#Support Vector Machine (rejected)
from sklearn.svm import SVR
#regressor = SVR()
from sklearn.ensemble import HistGradientBoostingRegressor
#regressor = HistGradientBoostingRegressor()

from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
#regressor = RandomForestRegressor()

# %%
# Train the model using training data
regressor.fit(x_train1, y_train1)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.7621439558577735, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05414335252326741, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=1, max_leaves=None,
#              min_child_weight=14, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
# Now the model is trained and can be used for making predictions
predicted_label = regressor.predict(x_test1)

# %%
predicted_label
# Out:
# array([ 566270.8 ,  630883.75,  453954.7 ,  590520.9 ,  606074.75,
#         577175.7 ,  349195.22,  368011.  ,  470134.88,  408598.7 ,
#         490353.88,  364410.1 ,  387610.47,  761471.9 ,  349195.22,
#         571446.94,  593657.25,  470134.88,  368011.  ,  428783.12,
#         459940.6 ,  470134.88,  593657.25,  387610.47,  741333.1 ,
#         453954.7 ,  372395.6 ,  349195.22,  577175.7 ,  450725.75,
#         387610.47,  741333.1 ,  349195.22,  364410.1 ,  573409.06,
#         580584.3 ,  349195.22,  457555.6 ,  751048.06,  349195.22,
#         913046.5 ,  364410.1 ,  571446.94,  522246.16,  510922.62,
#         571999.56,  449990.94,  761471.9 ,  371293.66,  751048.06,
#         908368.25,  585130.44,  470134.88,  459130.88,  480626.72,
#         585130.44,  364410.1 ,  349195.22,  457555.6 ,  577175.7 ,
#         387610.47,  492315.94,  368011.  ,  649148.2 ,  459130.88,
#         418767.94,  364410.1 ,  470134.88,  391211.38,  630883.75,
#         472096.94,  349195.22,  579954.3 ,  443916.  ,  573409.06,
#         459130.88,  418767.94,  640598.7 ,  472096.94,  632845.9 ,
#         349195.22,  349195.22,  467976.5 ,  599553.94,  571446.94,
#         593657.25,  908368.25,  349195.22,  453954.7 ,  640598.7 ,
#         398614.47,  403553.06,  364410.1 , 1017418.06,  642560.8 ,
#         364410.1 ,  387610.47,  583552.6 ,  464958.7 ,  461092.94,
#         470134.88,  510922.62,  349195.22,  464693.84,  459130.88,
#         502265.6 , 1881387.5 ,  495127.34,  349195.22,  642560.8 ,
#         846029.3 ,  512884.7 ,  761471.9 ,  459940.6 ,  531084.  ,
#         585130.44,  453954.7 ,  585130.44,  510922.62,  871921.25,
#         500303.53,  459130.88,  364410.1 ,  472096.94,  802597.1 ,
#         372395.6 ,  349195.22,  630883.75,  531553.06,  462731.78,
#         730783.75,  472096.94,  349195.22,  460838.25,  871921.25,
#         761471.9 ,  761471.9 ,  472096.94,  364410.1 ,  464958.7 ,
#        1647801.8 ,  403553.06, 1322878.4 ,  398614.47,  632845.9 ,
#         502265.6 ,  472096.94,  640598.7 ,  730783.75,  536812.75,
#         763434.  ,  387610.47,  464958.7 ,  457555.6 ,  802597.1 ,
#         585130.44,  571446.94,  499926.4 ,  536812.75,  610753.  ,
#         425651.5 ,  840400.94,  364410.1 ,  349195.22,  429771.94,
#         457555.6 ,  566270.8 ,  640598.7 ,  470134.88,  577175.7 ,
#         587092.56,  418833.47,  630883.75,  617818.4 ,  364410.1 ,
#         640598.7 ,  761471.9 ,  763434.  ,  571446.94,  470134.88,
#         461092.94,  730783.75,  387610.47,  349195.22,  841351.06,
#         751048.06,  600235.8 ,  779736.3 ,  630883.75,  579954.3 ,
#         461092.94,  571446.94,  429771.94,  349195.22,  429771.94,
#         418767.94,  871921.25,  418767.94,  470134.88,  571446.94,
#         464693.84,  630883.75,  761471.9 ,  630883.75,  502265.6 ,
#         761471.9 ,  464693.84,  364410.1 ,  349195.22,  349195.22,
#         349195.22,  600235.8 ,  571446.94,  349195.22,  457555.6 ,
#         349195.22,  490409.5 ,  841233.1 ,  425651.5 ,  585130.44,
#         581590.5 ,  460838.25,  735579.94,  418767.94,  428783.12,
#         349195.22,  472096.94,  470559.7 ,  364410.1 ,  464958.7 ,
#         461092.94,  449990.94,  510922.62,  453954.7 ,  630883.75,
#         457555.6 ,  500303.53,  913046.5 ,  577175.7 ,  761471.9 ,
#         464958.7 ,  349195.22,  459940.6 ,  579137.8 ,  589711.4 ,
#         730783.75,  531084.  ,  464958.7 ,  349195.22,  732745.9 ,
#         470134.88,  349195.22,  349195.22,  459130.88, 1241395.4 ,
#        1254385.9 ,  690420.9 ,  453954.7 ,  470134.88,  354240.84,
#         585130.44,  500303.53,  577175.7 ,  429771.94,  375414.1 ,
#         418767.94,  418767.94,  571999.56,  464693.84,  573409.06,
#         642560.8 ,  500303.53,  461092.94,  372395.6 ,  368011.  ,
#         730783.75,  349195.22,  573409.06,  422368.84,  640598.7 ,
#         349195.22,  349195.22,  867962.6 ,  571446.94,  349195.22,
#         364410.1 ,  635422.56,  820861.56,  422368.84,  587092.56,
#         349195.22,  871921.25,  349195.22,  779736.3 ,  510922.62,
#         398614.47, 1241395.4 ,  566270.8 ,  490353.88,  846029.3 ,
#         531084.  ,  640598.7 ,  544767.5 ,  418767.94,  349195.22,
#         571446.94,  761471.9 ,  524208.25,  536812.75,  470134.88,
#         364410.1 ,  577175.7 ,  640598.7 ,  462731.78,  730783.75,
#         464958.7 ,  906968.7 ,  571446.94,  349195.22,  422368.84,
#         630883.75,  364410.1 ,  749048.2 ,  508618.34,  761471.9 ,
#         464958.7 ,  418767.94,  470559.7 ,  375414.1 ,  500303.53,
#         640598.7 , 1241395.4 ,  913046.5 ,  541227.56,  461092.94,
#         630883.75,  349195.22,  443785.44,  495127.34,  418767.94,
#         418767.94,  579954.3 ,  867243.  ,  364410.1 ,  640598.7 ,
#         630883.75, 1555616.6 ,  460838.25,  461092.94,  464958.7 ,
#         585130.44,  630883.75,  630883.75,  989197.75,  349195.22,
#         462731.78,  422368.84,  529187.1 ,  585130.44,  461092.94,
#         349195.22, 1459790.8 ,  630883.75,  349195.22,  464958.7 ,
#         464693.84,  372395.6 ,  502265.6 ,  403553.06,  457555.6 ,
#         364410.1 ,  500303.53,  368011.  ,  585130.44,  510922.62,
#         761471.9 ,  354240.84,  453954.7 ,  573409.06,  600235.8 ,
#         429771.94,  375414.1 ,  779736.3 ,  495127.34,  460838.25,
#         480626.72,  387610.47, 1012739.8 ,  681896.3 ,  349195.22,
#         349195.22,  387610.47,  566270.8 ,  585130.44,  434611.38,
#         459130.88,  599553.94,  453954.7 , 1884769.6 ,  640598.7 ,
#         459130.88,  573409.06,  490353.88,  732745.9 ,  470559.7 ,
#        1169245.6 ,  418767.94,  513609.88,  422368.84,  453954.7 ,
#         466014.44,  846029.3 ,  492315.94,  349195.22,  536812.75,
#         422368.84,  802597.1 ,  569580.25,  470134.88,  354240.84,
#         453954.7 ,  630883.75,  571446.94,  349195.22,  593657.25,
#        1130946.1 ,  464693.84,  459130.88,  585130.44,  364410.1 ,
#         761471.9 ,  429771.94,  571446.94,  583552.6 ,  470134.88,
#        1130946.1 ,  461092.94,  761471.9 ,  349195.22,  438301.72,
#         387610.47,  364410.1 ,  569580.25,  459130.88,  820861.56,
#         640598.7 ,  349195.22,  398614.47,  474974.3 ,  630883.75,
#         422368.84,  349195.22,  472096.94,  429771.94,  349195.22,
#         464693.84,  459130.88,  566270.8 ,  636063.1 ,  730783.75,
#         502265.6 ,  349195.22, 1972452.9 ,  621372.1 ,  418767.94,
#         464693.84,  741333.1 ,  443916.  ,  429771.94,  372395.6 ,
#         438739.8 ,  460838.25,  398614.47,  364410.1 ,  462731.78,
#         871921.25,  467976.5 ,  841233.1 ,  741333.1 ,  721109.  ,
#         761471.9 ,  364410.1 ,  349195.22,  566270.8 ,  398614.47,
#         434611.38, 1972452.9 ,  349195.22,  470134.88,  687625.06,
#         577175.7 ,  349195.22,  349195.22,  391211.38,  422368.84,
#         462731.78,  492315.94,  571446.94,  690420.9 ,  453954.7 ,
#         418767.94,  349195.22,  349195.22,  490409.5 ,  585130.44,
#         585130.44,  418767.94,  349195.22,  571999.56,  761471.9 ,
#         566270.8 ,  732745.9 ,  545862.8 ,  761471.9 ,  571446.94,
#         349195.22,  472096.94, 1793704.2 ,  429771.94,  593657.25,
#         610753.  ,  470134.88,  573409.06,  349195.22,  349195.22,
#         429771.94,  473488.47,  459940.6 ,  500303.53,  500303.53,
#         387610.47,  349195.22,  349195.22,  462731.78,  571446.94,
#         375414.1 ,  470134.88,  579137.8 ,  375414.1 , 1241395.4 ,
#         364410.1 ,  462731.78, 1012298.44,  349195.22,  461092.94,
#         425651.5 ,  449990.94,  549817.5 , 1241395.4 ,  630883.75,
#         640598.7 ,  459940.6 ,  533515.2 ,  585130.44,  589711.4 ,
#        1130946.1 ,  457555.6 , 1793704.2 ,  364410.1 ,  500303.53,
#         630883.75,  536812.75,  735579.94,  364410.1 ,  457555.6 ,
#         741333.1 ,  464958.7 ,  459940.6 ,  418767.94,  571446.94,
#         587092.56,  840400.94,  428783.12,  544767.5 ,  364410.1 ,
#         571446.94,  464958.7 ,  737542.06,  871921.25,  642560.8 ,
#         467976.5 ,  418767.94,  573409.06,  349195.22,  470134.88,
#         802597.1 ,  470134.88,  418767.94,  737542.06, 1537352.2 ,
#         642560.8 ,  391211.38,  387610.47,  398614.47,  730783.75,
#         531553.06,  470134.88,  472096.94,  391211.38,  585130.44,
#         978412.  ,  372395.6 ,  418767.94,  593657.25,  630883.75,
#         886227.06,  630883.75,  349195.22,  531084.  ,  878748.4 ,
#         418767.94,  470559.7 ,  464958.7 ,  453954.7 ,  364410.1 ,
#         395633.1 ,  394494.03,  403553.06,  761471.9 ,  585130.44,
#         459130.88,  587092.56,  349195.22,  762234.25,  630883.75,
#         387610.47,  571446.94,  505499.8 ,  364410.1 ,  871921.25,
#         802597.1 ,  569580.25,  531084.  , 1149210.4 ,  461092.94,
#         372395.6 ,  908368.25,  630883.75,  802597.1 ,  950850.3 ,
#         761471.9 ,  481883.22,  472096.94,  871921.25,  349195.22,
#         913046.5 ,  453954.7 ,  364410.1 ,  640598.7 ,  571446.94,
#         403553.06,  453954.7 ,  577175.7 ,  364410.1 ,  946172.06,
#         580584.3 ,  871921.25,  721109.  ,  349195.22,  640598.7 ,
#         522246.16,  571446.94,  418767.94,  349195.22,  635422.56,
#         630883.75,  472096.94,  571446.94,  349195.22,  500303.53,
#         571446.94,  354240.84, 1099805.1 ,  453954.7 ,  403553.06,
#         461092.94,  566270.8 ,  387610.47,  492315.94,  566270.8 ,
#         449990.94,  364410.1 ,  403553.06,  349195.22,  730783.75,
#         466014.44,  751048.06,  730783.75,  571446.94,  453954.7 ,
#         871921.25,  630883.75,  820861.56,  472096.94,  973733.75,
#         585130.44,  462731.78,  349195.22,  761471.9 ,  445878.06,
#         349195.22,  510922.62,  429771.94,  364410.1 ,  403553.06,
#         472096.94,  418767.94,  349195.22,  571446.94, 1241395.4 ,
#         585130.44,  391211.38,  687625.06,  492315.94,  871921.25,
#         459130.88,  364410.1 ,  349195.22,  459130.88,  472096.94,
#         585130.44,  349195.22,  599553.94,  349195.22,  579954.3 ,
#         500303.53,  364410.1 ,  429771.94,  587092.56,  585130.44,
#         499926.4 ,  732745.9 ,  541227.56,  372395.6 ,  913046.5 ,
#        1017418.06,  585130.44,  571446.94,  577175.7 ,  429771.94,
#         580584.3 ,  761471.9 ,  470134.88,  349195.22,  464693.84,
#         349195.22,  730783.75,  453954.7 ,  536812.75,  478664.66,
#         349195.22, 1478363.4 ,  573181.2 ,  368011.  ,  405582.75,
#         522246.16,  470134.88,  500303.53,  418767.94,  467976.5 ,
#         470134.88,  513609.88,  871921.25,  490353.88,  461092.94,
#         761471.9 ,  398614.47,  422368.84,  577175.7 ,  349195.22,
#         571446.94,  349195.22,  730783.75,  531084.  ,  640598.7 ,
#         418767.94,  349195.22,  398614.47,  735579.94,  499926.4 ,
#         418767.94,  478664.66,  779736.3 , 1149210.4 ,  349195.22,
#         453954.7 ,  464958.7 ,  761471.9 ,  460838.25,  761471.9 ,
#         377441.22,  429771.94,  472096.94,  531084.  ,  349195.22,
#         425651.5 ,  761471.9 ,  585130.44,  732745.9 ,  372395.6 ,
#         349195.22,  349195.22,  453954.7 ,  387610.47,  761471.9 ,
#         585130.44,  761471.9 ,  730783.75,  425651.5 ,  422368.84,
#         470134.88,  470134.88, 1236717.2 ,  387610.47,  462731.78,
#         573409.06,  429771.94,  640598.7 ,  453954.7 ,  603394.9 ,
#         371293.66,  453954.7 ,  630883.75,  466014.44,  681896.3 ,
#         470134.88,  761471.9 ,  364410.1 ,  349195.22,  571446.94,
#         470134.88,  349195.22,  422368.84,  429771.94,  941377.7 ,
#         398614.47,  470134.88,  571446.94,  422368.84,  459940.6 ,
#         599854.94,  640598.7 ,  398614.47,  571999.56,  495127.34,
#         871921.25,  349195.22,  459130.88,  488399.34,  630883.75,
#         730783.75,  472096.94,  364410.1 ,  349195.22,  459940.6 ,
#         640598.7 ,  462731.78,  470134.88,  571446.94,  418767.94,
#         871921.25,  470134.88, 1241395.4 ,  429771.94,  375414.1 ,
#         349195.22,  495127.34,  422368.84,  464693.84,  730783.75,
#         536812.75,  349195.22,  577175.7 ,  640598.7 ,  422368.84,
#         453954.7 ,  522246.16,  453954.7 ,  474974.3 ,  364410.1 ,
#         804559.25,  630883.75,  571446.94,  585130.44,  630883.75,
#         464693.84,  364410.1 ,  585130.44,  640598.7 ,  462731.78,
#         690420.9 ,  761471.9 ,  761471.9 ,  387610.47,  732745.9 ,
#         349195.22,  364410.1 , 1241395.4 ,  459130.88,  593657.25,
#         571446.94,  349195.22,  418767.94,  429771.94,  500303.53,
#         464693.84,  453954.7 ,  761471.9 ,  418767.94,  453954.7 ,
#         364410.1 ,  950850.3 ,  545862.8 ,  577175.7 ,  349195.22,
#         405582.75,  375414.1 ,  858665.4 ,  573409.06,  422368.84],
#       dtype=float32)

# %%
from sklearn.metrics import median_absolute_error
from sklearn.metrics import max_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import explained_variance_score
from sklearn.metrics import max_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics  import f1_score

print('MSE Score :',mean_squared_error(y_test1, predicted_label)) #Mean squared error(MSE)
print ('R2 Score :',r2_score(y_test1,predicted_label)) #R² score
print ('MAE Score :',mean_absolute_error(y_test1,predicted_label)) #Mean absolute error
#print('Explained Variance Score :',explained_variance_score(y_test, predicted_label)) #reject
print ('MedAE Score :',median_absolute_error(y_test1,predicted_label))#Median absolute error(MedAE)
# Out:
# MSE Score : 72215448694.60112
# R2 Score : 0.4078390073974316
# MAE Score : 177824.4540119989
# MedAE Score : 134071.078125

# %%
# Now predict a single value using an input with the same number of features
single_input = [[5.0,	2.00,	2330]]  # Example input (replace with actual values)
single_prediction = regressor.predict(single_input)

print("Predicted value:", single_prediction[0])
# Out:
# Predicted value: 574539.8

# %% [markdown]
# Hyper Parameter Tuning

# %%
# !pip install optuna
# Out:
# Requirement already satisfied: optuna in /usr/local/lib/python3.10/dist-packages (4.1.0)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (1.14.0)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.10/dist-packages (from optuna) (6.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.36)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.6)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (1.3.6)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error
import optuna

def objective(trial):
  params={
      "objective":"reg:squarederror",
      "n_estimators":1000,
      "verbosity":0,
      "learning_rate": trial.suggest_float("learning_rate",1e-3,0.1,log=True),
      "max_depth":trial.suggest_int("max_depth",1,10),
      "subsample":trial.suggest_float("subsample",0.05,1.0),
      "colsample_bytree":trial.suggest_float("colsample_bytree",0.05,1.0),
      "min_child_weight":trial.suggest_int("min_child_weight",1,20),
  }

  model = xgb.XGBRegressor(**params)
  model.fit(x_train1, y_train1)
  predictions = model.predict(x_test1)
  r = r2_score(y_test1, predictions)
  return r

# %%
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)
# Out:
# [I 2024-11-26 05:14:45,350] A new study created in memory with name: no-name-ef7c0cd6-1832-4ad7-8653-4e580d90ee0a
# [I 2024-11-26 05:14:47,768] Trial 0 finished with value: 0.3409525594536499 and parameters: {'learning_rate': 0.03740790302645541, 'max_depth': 4, 'subsample': 0.47305386172151176, 'colsample_bytree': 0.49941449643891583, 'min_child_weight': 7}. Best is trial 0 with value: 0.3409525594536499.
# [I 2024-11-26 05:14:49,743] Trial 1 finished with value: 0.34673241844171454 and parameters: {'learning_rate': 0.024744035641831273, 'max_depth': 7, 'subsample': 0.5056969172360802, 'colsample_bytree': 0.6225103673880833, 'min_child_weight': 15}. Best is trial 1 with value: 0.34673241844171454.
# [I 2024-11-26 05:14:58,067] Trial 2 finished with value: 0.31502437401972483 and parameters: {'learning_rate': 0.003910427769211515, 'max_depth': 10, 'subsample': 0.9805009711848777, 'colsample_bytree': 0.1603259214574752, 'min_child_weight': 9}. Best is trial 1 with value: 0.34673241844171454.
# [I 2024-11-26 05:15:04,099] Trial 3 finished with value: 0.31857508310657956 and parameters: {'learning_rate': 0.0042951855676291685, 'max_depth': 10, 'subsample': 0.7946295107463754, 'colsample_bytree': 0.2380083194939837, 'min_child_weight': 5}. Best is trial 1 with value: 0.34673241844171454.
# [I 2024-11-26 05:15:04,485] Trial 4 finished with value: 0.3376768832226541 and parameters: {'learning_rate': 0.0695088423010373, 'max_depth': 5, 'subsample': 0.13047463730774111, 'colsample_bytree': 0.31563317877765334, 'min_child_weight': 17}. Best is trial 1 with value: 0.34673241844171454.
# [I 2024-11-26 05:15:04,745] Trial 5 finished with value: 0.29980331822501005 and parameters: {'learning_rate': 0.019800429233907114, 'max_depth': 2, 'subsample': 0.09745763533329992, 'colsample_bytree': 0.3266587108688916, 'min_child_weight': 10}. Best is trial 1 with value: 0.34673241844171454.
# [I 2024-11-26 05:15:05,148] Trial 6 finished with value: 0.31962855223963405 and parameters: {'learning_rate': 0.005175930733463258, 'max_depth': 4, 'subsample': 0.30114258155305845, 'colsample_bytree': 0.4987396742774058, 'min_child_weight': 2}. Best is trial 1 with value: 0.34673241844171454.
# [I 2024-11-26 05:15:05,457] Trial 7 finished with value: 0.3600321263159517 and parameters: {'learning_rate': 0.02236176843897545, 'max_depth': 3, 'subsample': 0.2212912769572865, 'colsample_bytree': 0.6537137652807568, 'min_child_weight': 17}. Best is trial 7 with value: 0.3600321263159517.
# [I 2024-11-26 05:15:05,780] Trial 8 finished with value: 0.30783333508558874 and parameters: {'learning_rate': 0.0018537329278196597, 'max_depth': 3, 'subsample': 0.14491411385583858, 'colsample_bytree': 0.3029677000795034, 'min_child_weight': 15}. Best is trial 7 with value: 0.3600321263159517.
# [I 2024-11-26 05:15:06,074] Trial 9 finished with value: 0.3535614372422784 and parameters: {'learning_rate': 0.0030607072220819806, 'max_depth': 2, 'subsample': 0.5133017375425024, 'colsample_bytree': 0.32476872586490274, 'min_child_weight': 18}. Best is trial 7 with value: 0.3600321263159517.
# [I 2024-11-26 05:15:06,681] Trial 10 finished with value: 0.35913055205887656 and parameters: {'learning_rate': 0.01131831805619295, 'max_depth': 7, 'subsample': 0.3151394196704245, 'colsample_bytree': 0.9728962970689776, 'min_child_weight': 20}. Best is trial 7 with value: 0.3600321263159517.
# [I 2024-11-26 05:15:07,789] Trial 11 finished with value: 0.35752389146463426 and parameters: {'learning_rate': 0.011248933256347035, 'max_depth': 8, 'subsample': 0.31119357849248486, 'colsample_bytree': 0.9586511734782024, 'min_child_weight': 20}. Best is trial 7 with value: 0.3600321263159517.
# [I 2024-11-26 05:15:10,500] Trial 12 finished with value: 0.34710703632580386 and parameters: {'learning_rate': 0.009685751941868694, 'max_depth': 7, 'subsample': 0.3079732960304191, 'colsample_bytree': 0.9979190897451865, 'min_child_weight': 13}. Best is trial 7 with value: 0.3600321263159517.
# [I 2024-11-26 05:15:11,752] Trial 13 finished with value: 0.4087134629820298 and parameters: {'learning_rate': 0.08874310819103276, 'max_depth': 1, 'subsample': 0.6781449587796808, 'colsample_bytree': 0.782765296507459, 'min_child_weight': 20}. Best is trial 13 with value: 0.4087134629820298.
# [I 2024-11-26 05:15:12,002] Trial 14 finished with value: 0.4086445972734576 and parameters: {'learning_rate': 0.08934635096577916, 'max_depth': 1, 'subsample': 0.7036513953993534, 'colsample_bytree': 0.7637123509005924, 'min_child_weight': 13}. Best is trial 13 with value: 0.4087134629820298.
# [I 2024-11-26 05:15:12,264] Trial 15 finished with value: 0.41068433840887997 and parameters: {'learning_rate': 0.09576703235112734, 'max_depth': 1, 'subsample': 0.7057200900559503, 'colsample_bytree': 0.7864317400178064, 'min_child_weight': 12}. Best is trial 15 with value: 0.41068433840887997.
# [I 2024-11-26 05:15:12,573] Trial 16 finished with value: 0.36884333874182695 and parameters: {'learning_rate': 0.0515688606387814, 'max_depth': 2, 'subsample': 0.6674003927655392, 'colsample_bytree': 0.7874877814563833, 'min_child_weight': 1}. Best is trial 15 with value: 0.41068433840887997.
# [I 2024-11-26 05:15:12,819] Trial 17 finished with value: 0.4105902449275721 and parameters: {'learning_rate': 0.09383148603081906, 'max_depth': 1, 'subsample': 0.8921386177828843, 'colsample_bytree': 0.8276346636670247, 'min_child_weight': 12}. Best is trial 15 with value: 0.41068433840887997.
# [I 2024-11-26 05:15:13,050] Trial 18 finished with value: 0.4080685891372854 and parameters: {'learning_rate': 0.04311662806072002, 'max_depth': 1, 'subsample': 0.9905209089642723, 'colsample_bytree': 0.8837754672241387, 'min_child_weight': 12}. Best is trial 15 with value: 0.41068433840887997.
# [I 2024-11-26 05:15:13,501] Trial 19 finished with value: 0.34488725593697167 and parameters: {'learning_rate': 0.03299494714145729, 'max_depth': 5, 'subsample': 0.85716240339578, 'colsample_bytree': 0.6462625443764184, 'min_child_weight': 8}. Best is trial 15 with value: 0.41068433840887997.
# [I 2024-11-26 05:15:13,837] Trial 20 finished with value: 0.2917090138004984 and parameters: {'learning_rate': 0.06232424223612656, 'max_depth': 3, 'subsample': 0.8769292678707861, 'colsample_bytree': 0.8623911850184481, 'min_child_weight': 6}. Best is trial 15 with value: 0.41068433840887997.
# [I 2024-11-26 05:15:14,092] Trial 21 finished with value: 0.41056108897442134 and parameters: {'learning_rate': 0.09268432159225413, 'max_depth': 1, 'subsample': 0.6413133802559975, 'colsample_bytree': 0.7468410955297462, 'min_child_weight': 11}. Best is trial 15 with value: 0.41068433840887997.
# [I 2024-11-26 05:15:14,361] Trial 22 finished with value: 0.4101230694757577 and parameters: {'learning_rate': 0.09810873246371489, 'max_depth': 1, 'subsample': 0.6303154225794055, 'colsample_bytree': 0.6980891045540326, 'min_child_weight': 11}. Best is trial 15 with value: 0.41068433840887997.
# [I 2024-11-26 05:15:14,663] Trial 23 finished with value: 0.37401956669073466 and parameters: {'learning_rate': 0.05966078453356303, 'max_depth': 2, 'subsample': 0.7803906966394486, 'colsample_bytree': 0.8588128145645169, 'min_child_weight': 14}. Best is trial 15 with value: 0.41068433840887997.
# [I 2024-11-26 05:15:14,915] Trial 24 finished with value: 0.40511800286407107 and parameters: {'learning_rate': 0.032621258753045515, 'max_depth': 1, 'subsample': 0.881845484107381, 'colsample_bytree': 0.5799448657847375, 'min_child_weight': 11}. Best is trial 15 with value: 0.41068433840887997.
# [I 2024-11-26 05:15:15,330] Trial 25 finished with value: 0.3138278412910245 and parameters: {'learning_rate': 0.06813046499732887, 'max_depth': 4, 'subsample': 0.5996577334748328, 'colsample_bytree': 0.7133336193265055, 'min_child_weight': 12}. Best is trial 15 with value: 0.41068433840887997.
# [I 2024-11-26 05:15:15,644] Trial 26 finished with value: 0.33270158892167023 and parameters: {'learning_rate': 0.09645973849371989, 'max_depth': 2, 'subsample': 0.43073653175376014, 'colsample_bytree': 0.45229040872993154, 'min_child_weight': 9}. Best is trial 15 with value: 0.41068433840887997.
# [I 2024-11-26 05:15:16,010] Trial 27 finished with value: 0.36516728639120144 and parameters: {'learning_rate': 0.01646339654247451, 'max_depth': 3, 'subsample': 0.7647665344132599, 'colsample_bytree': 0.9058145731272236, 'min_child_weight': 4}. Best is trial 15 with value: 0.41068433840887997.
# [I 2024-11-26 05:15:16,278] Trial 28 finished with value: 0.254349482956268 and parameters: {'learning_rate': 0.0010486485849233909, 'max_depth': 1, 'subsample': 0.5607882808285385, 'colsample_bytree': 0.8074748448977819, 'min_child_weight': 15}. Best is trial 15 with value: 0.41068433840887997.
# [I 2024-11-26 05:15:16,679] Trial 29 finished with value: 0.3291814824925893 and parameters: {'learning_rate': 0.03251274952640495, 'max_depth': 4, 'subsample': 0.41660098708439286, 'colsample_bytree': 0.5830137064604878, 'min_child_weight': 7}. Best is trial 15 with value: 0.41068433840887997.
# [I 2024-11-26 05:15:16,983] Trial 30 finished with value: 0.37150957337258195 and parameters: {'learning_rate': 0.049780075540109964, 'max_depth': 2, 'subsample': 0.9248157072684728, 'colsample_bytree': 0.7104132546793352, 'min_child_weight': 10}. Best is trial 15 with value: 0.41068433840887997.
# [I 2024-11-26 05:15:17,251] Trial 31 finished with value: 0.41256043415884047 and parameters: {'learning_rate': 0.09727039399274644, 'max_depth': 1, 'subsample': 0.6102017075523476, 'colsample_bytree': 0.7192085856002597, 'min_child_weight': 11}. Best is trial 31 with value: 0.41256043415884047.
# [I 2024-11-26 05:15:17,507] Trial 32 finished with value: 0.4102917590241607 and parameters: {'learning_rate': 0.07454941257054057, 'max_depth': 1, 'subsample': 0.7404598576208994, 'colsample_bytree': 0.8234006314308886, 'min_child_weight': 13}. Best is trial 31 with value: 0.41256043415884047.
# [I 2024-11-26 05:15:17,813] Trial 33 finished with value: 0.36606028911288835 and parameters: {'learning_rate': 0.047874726271935, 'max_depth': 2, 'subsample': 0.5860096979741716, 'colsample_bytree': 0.728849807462052, 'min_child_weight': 9}. Best is trial 31 with value: 0.41256043415884047.
# [I 2024-11-26 05:15:18,167] Trial 34 finished with value: 0.3616346131412823 and parameters: {'learning_rate': 0.03980676624950922, 'max_depth': 3, 'subsample': 0.8248300342563482, 'colsample_bytree': 0.5752808199604785, 'min_child_weight': 12}. Best is trial 31 with value: 0.41256043415884047.
# [I 2024-11-26 05:15:18,736] Trial 35 finished with value: 0.20557594911789812 and parameters: {'learning_rate': 0.07706283729050858, 'max_depth': 6, 'subsample': 0.46014930392120723, 'colsample_bytree': 0.9224386364789939, 'min_child_weight': 15}. Best is trial 31 with value: 0.41256043415884047.
# [I 2024-11-26 05:15:18,986] Trial 36 finished with value: 0.4121276987995981 and parameters: {'learning_rate': 0.06639073494024202, 'max_depth': 1, 'subsample': 0.7322475483670149, 'colsample_bytree': 0.11538432887384165, 'min_child_weight': 10}. Best is trial 31 with value: 0.41256043415884047.
# [I 2024-11-26 05:15:19,665] Trial 37 finished with value: 0.3231738101309998 and parameters: {'learning_rate': 0.026691098073332253, 'max_depth': 9, 'subsample': 0.7081339835585301, 'colsample_bytree': 0.1094746884258565, 'min_child_weight': 8}. Best is trial 31 with value: 0.41256043415884047.
# [I 2024-11-26 05:15:19,981] Trial 38 finished with value: 0.3781750921518965 and parameters: {'learning_rate': 0.06147509278107679, 'max_depth': 2, 'subsample': 0.9116347545539811, 'colsample_bytree': 0.42543564909844483, 'min_child_weight': 10}. Best is trial 31 with value: 0.41256043415884047.
# [I 2024-11-26 05:15:20,324] Trial 39 finished with value: 0.3666909676005565 and parameters: {'learning_rate': 0.01742499927039439, 'max_depth': 3, 'subsample': 0.8283893036769208, 'colsample_bytree': 0.18478599116973127, 'min_child_weight': 14}. Best is trial 31 with value: 0.41256043415884047.
# [I 2024-11-26 05:15:20,741] Trial 40 finished with value: 0.3273377243623492 and parameters: {'learning_rate': 0.00820763572271432, 'max_depth': 4, 'subsample': 0.7332456677780812, 'colsample_bytree': 0.3775373046757041, 'min_child_weight': 8}. Best is trial 31 with value: 0.41256043415884047.
# [I 2024-11-26 05:15:21,004] Trial 41 finished with value: 0.4133505663130943 and parameters: {'learning_rate': 0.07784154703992277, 'max_depth': 1, 'subsample': 0.6386141032036882, 'colsample_bytree': 0.6585627978904567, 'min_child_weight': 10}. Best is trial 41 with value: 0.4133505663130943.
# [I 2024-11-26 05:15:21,241] Trial 42 finished with value: 0.4119499321186376 and parameters: {'learning_rate': 0.0745155995122987, 'max_depth': 1, 'subsample': 0.9356082951091056, 'colsample_bytree': 0.6670552441318631, 'min_child_weight': 9}. Best is trial 41 with value: 0.4133505663130943.
# [I 2024-11-26 05:15:21,533] Trial 43 finished with value: 0.3649020841838372 and parameters: {'learning_rate': 0.053748745987913515, 'max_depth': 2, 'subsample': 0.5168371206402036, 'colsample_bytree': 0.518706200408275, 'min_child_weight': 7}. Best is trial 41 with value: 0.4133505663130943.
# [I 2024-11-26 05:15:22,880] Trial 44 finished with value: 0.4158957589045583 and parameters: {'learning_rate': 0.07165462315663809, 'max_depth': 1, 'subsample': 0.5511886581894913, 'colsample_bytree': 0.6679294922791794, 'min_child_weight': 9}. Best is trial 44 with value: 0.4158957589045583.
# [I 2024-11-26 05:15:24,418] Trial 45 finished with value: 0.33979261778642 and parameters: {'learning_rate': 0.0711150709856399, 'max_depth': 2, 'subsample': 0.38622592925903754, 'colsample_bytree': 0.6559504709275169, 'min_child_weight': 5}. Best is trial 44 with value: 0.4158957589045583.
# [I 2024-11-26 05:15:25,885] Trial 46 finished with value: 0.4087949520484153 and parameters: {'learning_rate': 0.03954001280581054, 'max_depth': 1, 'subsample': 0.5538817692409852, 'colsample_bytree': 0.05984194551832642, 'min_child_weight': 9}. Best is trial 44 with value: 0.4158957589045583.
# [I 2024-11-26 05:15:26,198] Trial 47 finished with value: 0.3703118206917627 and parameters: {'learning_rate': 0.026563796225824637, 'max_depth': 2, 'subsample': 0.48611526839468255, 'colsample_bytree': 0.625538020423029, 'min_child_weight': 10}. Best is trial 44 with value: 0.4158957589045583.
# [I 2024-11-26 05:15:26,466] Trial 48 finished with value: 0.4072709069472097 and parameters: {'learning_rate': 0.07701894986809572, 'max_depth': 1, 'subsample': 0.9557394066050999, 'colsample_bytree': 0.6710089882987755, 'min_child_weight': 6}. Best is trial 44 with value: 0.4158957589045583.
# [I 2024-11-26 05:15:26,844] Trial 49 finished with value: 0.3631943388810055 and parameters: {'learning_rate': 0.05699794211516362, 'max_depth': 3, 'subsample': 0.6137245673164666, 'colsample_bytree': 0.26004205881857967, 'min_child_weight': 9}. Best is trial 44 with value: 0.4158957589045583.
# [I 2024-11-26 05:15:27,375] Trial 50 finished with value: 0.31601077613332607 and parameters: {'learning_rate': 0.0058026972857468245, 'max_depth': 6, 'subsample': 0.6614186172169131, 'colsample_bytree': 0.5572209428042927, 'min_child_weight': 8}. Best is trial 44 with value: 0.4158957589045583.
# [I 2024-11-26 05:15:27,630] Trial 51 finished with value: 0.41228882067397166 and parameters: {'learning_rate': 0.07960126723039378, 'max_depth': 1, 'subsample': 0.5405356190528312, 'colsample_bytree': 0.6168064773415818, 'min_child_weight': 11}. Best is trial 44 with value: 0.4158957589045583.
# [I 2024-11-26 05:15:27,897] Trial 52 finished with value: 0.4100645636454545 and parameters: {'learning_rate': 0.08019652707409587, 'max_depth': 1, 'subsample': 0.5326495402166497, 'colsample_bytree': 0.6125688107212311, 'min_child_weight': 10}. Best is trial 44 with value: 0.4158957589045583.
# [I 2024-11-26 05:15:28,177] Trial 53 finished with value: 0.4136393306636027 and parameters: {'learning_rate': 0.04832952725495531, 'max_depth': 1, 'subsample': 0.5685911214067461, 'colsample_bytree': 0.6827642135605522, 'min_child_weight': 11}. Best is trial 44 with value: 0.4158957589045583.
# [I 2024-11-26 05:15:28,476] Trial 54 finished with value: 0.32757218932639265 and parameters: {'learning_rate': 0.04541040446473467, 'max_depth': 2, 'subsample': 0.3620949567695494, 'colsample_bytree': 0.5013843386066461, 'min_child_weight': 11}. Best is trial 44 with value: 0.4158957589045583.
# [I 2024-11-26 05:15:28,726] Trial 55 finished with value: 0.41815726928641506 and parameters: {'learning_rate': 0.062064335226537946, 'max_depth': 1, 'subsample': 0.5811791635408664, 'colsample_bytree': 0.5465522186729549, 'min_child_weight': 13}. Best is trial 55 with value: 0.41815726928641506.
# [I 2024-11-26 05:15:29,009] Trial 56 finished with value: 0.4171336615405956 and parameters: {'learning_rate': 0.053866269131408406, 'max_depth': 1, 'subsample': 0.5873894299110882, 'colsample_bytree': 0.6199390040858351, 'min_child_weight': 13}. Best is trial 55 with value: 0.41815726928641506.
# [I 2024-11-26 05:15:29,551] Trial 57 finished with value: 0.34263573914887335 and parameters: {'learning_rate': 0.021993004303212833, 'max_depth': 8, 'subsample': 0.48362752003523735, 'colsample_bytree': 0.5451228841755678, 'min_child_weight': 13}. Best is trial 55 with value: 0.41815726928641506.
# [I 2024-11-26 05:15:29,843] Trial 58 finished with value: 0.37466742185739876 and parameters: {'learning_rate': 0.035986598037755765, 'max_depth': 2, 'subsample': 0.5922566128173243, 'colsample_bytree': 0.46046423237820194, 'min_child_weight': 14}. Best is trial 55 with value: 0.41815726928641506.
# [I 2024-11-26 05:15:30,126] Trial 59 finished with value: 0.4161354620749611 and parameters: {'learning_rate': 0.05374995611221332, 'max_depth': 1, 'subsample': 0.6373869748419828, 'colsample_bytree': 0.6838765976387345, 'min_child_weight': 14}. Best is trial 55 with value: 0.41815726928641506.
# [I 2024-11-26 05:15:30,450] Trial 60 finished with value: 0.40368733533465917 and parameters: {'learning_rate': 0.0026799003028319334, 'max_depth': 2, 'subsample': 0.6793981434554874, 'colsample_bytree': 0.6866195032914784, 'min_child_weight': 17}. Best is trial 55 with value: 0.41815726928641506.
# [I 2024-11-26 05:15:30,705] Trial 61 finished with value: 0.41927511177070576 and parameters: {'learning_rate': 0.05414335252326741, 'max_depth': 1, 'subsample': 0.5720719776204785, 'colsample_bytree': 0.7621439558577735, 'min_child_weight': 14}. Best is trial 61 with value: 0.41927511177070576.
# [I 2024-11-26 05:15:30,982] Trial 62 finished with value: 0.41467595260604506 and parameters: {'learning_rate': 0.05381480875473523, 'max_depth': 1, 'subsample': 0.5706359962825103, 'colsample_bytree': 0.7583485349898348, 'min_child_weight': 18}. Best is trial 61 with value: 0.41927511177070576.
# [I 2024-11-26 05:15:31,262] Trial 63 finished with value: 0.4161226540459245 and parameters: {'learning_rate': 0.030595446506413243, 'max_depth': 1, 'subsample': 0.5704069187686363, 'colsample_bytree': 0.7433704450891305, 'min_child_weight': 16}. Best is trial 61 with value: 0.41927511177070576.
# [I 2024-11-26 05:15:31,561] Trial 64 finished with value: 0.3659605411706681 and parameters: {'learning_rate': 0.029691588388954554, 'max_depth': 2, 'subsample': 0.4970287542970311, 'colsample_bytree': 0.7548111633464545, 'min_child_weight': 16}. Best is trial 61 with value: 0.41927511177070576.
# [I 2024-11-26 05:15:31,823] Trial 65 finished with value: 0.4149442133733857 and parameters: {'learning_rate': 0.042214111393237615, 'max_depth': 1, 'subsample': 0.4484753414785755, 'colsample_bytree': 0.7585776833023594, 'min_child_weight': 19}. Best is trial 61 with value: 0.41927511177070576.
# [I 2024-11-26 05:15:32,216] Trial 66 finished with value: 0.36872469312953104 and parameters: {'learning_rate': 0.04320508482277322, 'max_depth': 3, 'subsample': 0.4575045506789176, 'colsample_bytree': 0.604099622233012, 'min_child_weight': 19}. Best is trial 61 with value: 0.41927511177070576.
# [I 2024-11-26 05:15:32,744] Trial 67 finished with value: 0.3030864082039534 and parameters: {'learning_rate': 0.03502264651958549, 'max_depth': 5, 'subsample': 0.42999326452685893, 'colsample_bytree': 0.7410812667797895, 'min_child_weight': 16}. Best is trial 61 with value: 0.41927511177070576.
# [I 2024-11-26 05:15:33,014] Trial 68 finished with value: 0.3993112217708813 and parameters: {'learning_rate': 0.014664927014168792, 'max_depth': 1, 'subsample': 0.2755059695155726, 'colsample_bytree': 0.8000049408538025, 'min_child_weight': 19}. Best is trial 61 with value: 0.41927511177070576.
# [I 2024-11-26 05:15:33,349] Trial 69 finished with value: 0.3570194994331223 and parameters: {'learning_rate': 0.058969914389277324, 'max_depth': 2, 'subsample': 0.5304934765042075, 'colsample_bytree': 0.8633466820266241, 'min_child_weight': 13}. Best is trial 61 with value: 0.41927511177070576.
# [I 2024-11-26 05:15:33,597] Trial 70 finished with value: 0.41393375223172546 and parameters: {'learning_rate': 0.0401493491759589, 'max_depth': 1, 'subsample': 0.6350123059594313, 'colsample_bytree': 0.8295775663373177, 'min_child_weight': 16}. Best is trial 61 with value: 0.41927511177070576.
# [I 2024-11-26 05:15:33,865] Trial 71 finished with value: 0.41520401433529175 and parameters: {'learning_rate': 0.05239566153094463, 'max_depth': 1, 'subsample': 0.5692388018846443, 'colsample_bytree': 0.7750088828791799, 'min_child_weight': 18}. Best is trial 61 with value: 0.41927511177070576.
# [I 2024-11-26 05:15:34,118] Trial 72 finished with value: 0.41558253544852974 and parameters: {'learning_rate': 0.02903551085120586, 'max_depth': 1, 'subsample': 0.5823005167635555, 'colsample_bytree': 0.7772385301750144, 'min_child_weight': 18}. Best is trial 61 with value: 0.41927511177070576.
# [I 2024-11-26 05:15:34,395] Trial 73 finished with value: 0.41460630824207456 and parameters: {'learning_rate': 0.022256829682041235, 'max_depth': 1, 'subsample': 0.6673886134112322, 'colsample_bytree': 0.785839558345149, 'min_child_weight': 18}. Best is trial 61 with value: 0.41927511177070576.
# [I 2024-11-26 05:15:34,689] Trial 74 finished with value: 0.37314037782882736 and parameters: {'learning_rate': 0.06379033216635112, 'max_depth': 2, 'subsample': 0.6102724968683902, 'colsample_bytree': 0.6358311137582163, 'min_child_weight': 17}. Best is trial 61 with value: 0.41927511177070576.
# [I 2024-11-26 05:15:34,967] Trial 75 finished with value: 0.4136437625202154 and parameters: {'learning_rate': 0.030405766697701606, 'max_depth': 1, 'subsample': 0.5085932455756719, 'colsample_bytree': 0.7072756129804941, 'min_child_weight': 15}. Best is trial 61 with value: 0.41927511177070576.
# [I 2024-11-26 05:15:35,249] Trial 76 finished with value: 0.41829491784346196 and parameters: {'learning_rate': 0.051680880496271744, 'max_depth': 1, 'subsample': 0.5818384458368324, 'colsample_bytree': 0.8232280375483839, 'min_child_weight': 14}. Best is trial 61 with value: 0.41927511177070576.
# [I 2024-11-26 05:15:35,520] Trial 77 finished with value: 0.41670256609571943 and parameters: {'learning_rate': 0.04732140943967762, 'max_depth': 1, 'subsample': 0.7028184752248372, 'colsample_bytree': 0.945390792910551, 'min_child_weight': 14}. Best is trial 61 with value: 0.41927511177070576.
# [I 2024-11-26 05:15:38,174] Trial 78 finished with value: 0.02307283787080494 and parameters: {'learning_rate': 0.08712760342105859, 'max_depth': 10, 'subsample': 0.7060200941154204, 'colsample_bytree': 0.9713092023688134, 'min_child_weight': 14}. Best is trial 61 with value: 0.41927511177070576.
# [I 2024-11-26 05:15:40,290] Trial 79 finished with value: 0.37452034669028467 and parameters: {'learning_rate': 0.06526132756272089, 'max_depth': 2, 'subsample': 0.6466468053320977, 'colsample_bytree': 0.9325515505700881, 'min_child_weight': 14}. Best is trial 61 with value: 0.41927511177070576.
# [I 2024-11-26 05:15:40,606] Trial 80 finished with value: 0.37573956925484076 and parameters: {'learning_rate': 0.04857241556070004, 'max_depth': 2, 'subsample': 0.6194568899113839, 'colsample_bytree': 0.9954812611393139, 'min_child_weight': 15}. Best is trial 61 with value: 0.41927511177070576.
# [I 2024-11-26 05:15:40,878] Trial 81 finished with value: 0.415138620798999 and parameters: {'learning_rate': 0.03586113871089471, 'max_depth': 1, 'subsample': 0.5820677766204538, 'colsample_bytree': 0.849053433527327, 'min_child_weight': 16}. Best is trial 61 with value: 0.41927511177070576.
# [I 2024-11-26 05:15:41,130] Trial 82 finished with value: 0.41812154373852806 and parameters: {'learning_rate': 0.05637201266343176, 'max_depth': 1, 'subsample': 0.5485402503886495, 'colsample_bytree': 0.8873578909339223, 'min_child_weight': 13}. Best is trial 61 with value: 0.41927511177070576.
# [I 2024-11-26 05:15:41,394] Trial 83 finished with value: 0.41733595856040717 and parameters: {'learning_rate': 0.05608836876594173, 'max_depth': 1, 'subsample': 0.5125235855483985, 'colsample_bytree': 0.8851134305381617, 'min_child_weight': 12}. Best is trial 61 with value: 0.41927511177070576.
# [I 2024-11-26 05:15:41,664] Trial 84 finished with value: 0.4098283629208129 and parameters: {'learning_rate': 0.05585977452825395, 'max_depth': 1, 'subsample': 0.6843107324394031, 'colsample_bytree': 0.8943145931430957, 'min_child_weight': 13}. Best is trial 61 with value: 0.41927511177070576.
# [I 2024-11-26 05:15:41,955] Trial 85 finished with value: 0.4174753698449353 and parameters: {'learning_rate': 0.043289657265053745, 'max_depth': 1, 'subsample': 0.5163630881243081, 'colsample_bytree': 0.9369309501060076, 'min_child_weight': 12}. Best is trial 61 with value: 0.41927511177070576.
# [I 2024-11-26 05:15:42,256] Trial 86 finished with value: 0.34630768789864796 and parameters: {'learning_rate': 0.06042806316079286, 'max_depth': 2, 'subsample': 0.5212194665111046, 'colsample_bytree': 0.9476813165820916, 'min_child_weight': 12}. Best is trial 61 with value: 0.41927511177070576.
# [I 2024-11-26 05:15:42,527] Trial 87 finished with value: 0.4127789655695949 and parameters: {'learning_rate': 0.04575977963178966, 'max_depth': 1, 'subsample': 0.7616482490711253, 'colsample_bytree': 0.9174269288666018, 'min_child_weight': 12}. Best is trial 61 with value: 0.41927511177070576.
# [I 2024-11-26 05:15:42,828] Trial 88 finished with value: 0.3493296611593706 and parameters: {'learning_rate': 0.03888593315916958, 'max_depth': 2, 'subsample': 0.47229185860387424, 'colsample_bytree': 0.8861208112197436, 'min_child_weight': 13}. Best is trial 61 with value: 0.41927511177070576.
# [I 2024-11-26 05:15:43,071] Trial 89 finished with value: 0.33844845301061344 and parameters: {'learning_rate': 0.04985816209138585, 'max_depth': 1, 'subsample': 0.08835734065605705, 'colsample_bytree': 0.9497132674280095, 'min_child_weight': 14}. Best is trial 61 with value: 0.41927511177070576.
# [I 2024-11-26 05:15:43,471] Trial 90 finished with value: 0.3147889226193523 and parameters: {'learning_rate': 0.06508535625158529, 'max_depth': 3, 'subsample': 0.392461202759522, 'colsample_bytree': 0.8703149354228694, 'min_child_weight': 15}. Best is trial 61 with value: 0.41927511177070576.
# [I 2024-11-26 05:15:43,777] Trial 91 finished with value: 0.41558071091280435 and parameters: {'learning_rate': 0.04488228739016496, 'max_depth': 1, 'subsample': 0.5463489937981633, 'colsample_bytree': 0.8356678644272184, 'min_child_weight': 14}. Best is trial 61 with value: 0.41927511177070576.
# [I 2024-11-26 05:15:44,051] Trial 92 finished with value: 0.41273817909335564 and parameters: {'learning_rate': 0.054919689905752356, 'max_depth': 1, 'subsample': 0.5964932741542225, 'colsample_bytree': 0.904312213693986, 'min_child_weight': 12}. Best is trial 61 with value: 0.41927511177070576.
# [I 2024-11-26 05:15:44,311] Trial 93 finished with value: 0.40745769832215983 and parameters: {'learning_rate': 0.08478940192703592, 'max_depth': 1, 'subsample': 0.65266223867466, 'colsample_bytree': 0.8044660108696933, 'min_child_weight': 13}. Best is trial 61 with value: 0.41927511177070576.
# [I 2024-11-26 05:15:44,584] Trial 94 finished with value: 0.41808650118265234 and parameters: {'learning_rate': 0.04032365982524106, 'max_depth': 1, 'subsample': 0.6252664837349483, 'colsample_bytree': 0.9710773592090073, 'min_child_weight': 13}. Best is trial 61 with value: 0.41927511177070576.
# [I 2024-11-26 05:15:44,889] Trial 95 finished with value: 0.3725517895211936 and parameters: {'learning_rate': 0.03702052891705137, 'max_depth': 2, 'subsample': 0.6299919904052803, 'colsample_bytree': 0.9992301002887312, 'min_child_weight': 12}. Best is trial 61 with value: 0.41927511177070576.
# [I 2024-11-26 05:15:45,148] Trial 96 finished with value: 0.4145775341557921 and parameters: {'learning_rate': 0.06794194905694327, 'max_depth': 1, 'subsample': 0.5020275230898412, 'colsample_bytree': 0.9697820480702499, 'min_child_weight': 13}. Best is trial 61 with value: 0.41927511177070576.
# [I 2024-11-26 05:15:45,402] Trial 97 finished with value: 0.414958022573481 and parameters: {'learning_rate': 0.05163676906789465, 'max_depth': 1, 'subsample': 0.6886317665635953, 'colsample_bytree': 0.9385929834539651, 'min_child_weight': 14}. Best is trial 61 with value: 0.41927511177070576.
# [I 2024-11-26 05:15:45,715] Trial 98 finished with value: 0.37075238590996007 and parameters: {'learning_rate': 0.04289811068901806, 'max_depth': 2, 'subsample': 0.6039679627097224, 'colsample_bytree': 0.9206789104567136, 'min_child_weight': 13}. Best is trial 61 with value: 0.41927511177070576.
# [I 2024-11-26 05:15:46,002] Trial 99 finished with value: 0.41493761067477974 and parameters: {'learning_rate': 0.05831157935221074, 'max_depth': 1, 'subsample': 0.5494562510426932, 'colsample_bytree': 0.8470222110397032, 'min_child_weight': 14}. Best is trial 61 with value: 0.41927511177070576.

# %%
print("Best Hyperparameters: ", study.best_params)
print("Best R2: ", study.best_value)
# Out:
# Best Hyperparameters:  {'learning_rate': 0.05414335252326741, 'max_depth': 1, 'subsample': 0.5720719776204785, 'colsample_bytree': 0.7621439558577735, 'min_child_weight': 14}
# Best R2:  0.41927511177070576
